# %% [markdown]
# # 🐬 comparison

# %%
from bluer_options import string
from bluer_ugv.README.ugvs.comparison.features.db import dict_of_feature_classes


from bluer_ugv.host import signature
from bluer_ugv.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🐬  bluer_ugv-7.263.1.bluer_sbc-9.166.1.bluer_ai-12.306.1.bluer_objects-6.330.1.bluer_options-5.204.1.blueness-3.118.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 08 November 2025, 13:57:45

# %% [markdown]
# ---

# %%
dict_of_feature_classes.keys()
# Out:
# dict_keys(['DYI', 'control', 'cost', 'payload', 'ps', 'range', 'size', 'speed', 'swarm', 'uv_delivery'])

# %% [markdown]
# ---

# %%
# END
